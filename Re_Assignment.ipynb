# %% [markdown]
# ---
#
# _You are currently looking at **version 1.1** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 1
#
# In this assignment, you'll be working with messy medical data and using regex to extract relevant infromation from the data.
#
# Each line of the `dates.txt` file corresponds to a medical note. Each note has a date that needs to be extracted, but each date is encoded in one of many formats.
#
# The goal of this assignment is to correctly identify all of the different date variants encoded in this dataset and to properly normalize and sort the dates.
#
# Here is a list of some of the variants you might encounter in this dataset:
# * 04/20/2009; 04/20/09; 4/20/09; 4/3/09
# * Mar-20-2009; Mar 20, 2009; March 20, 2009;  Mar. 20, 2009; Mar 20 2009;
# * 20 Mar 2009; 20 March 2009; 20 Mar. 2009; 20 March, 2009
# * Mar 20th, 2009; Mar 21st, 2009; Mar 22nd, 2009
# * Feb 2009; Sep 2009; Oct 2010
# * 6/2008; 12/2009
# * 2009; 2010
#
# Once you have extracted these date patterns from the text, the next step is to sort them in ascending chronological order accoring to the following rules:
# * Assume all dates in xx/xx/xx format are mm/dd/yy
# * Assume all dates where year is encoded in only two digits are years from the 1900's (e.g. 1/5/89 is January 5th, 1989)
# * If the day is missing (e.g. 9/2009), assume it is the first day of the month (e.g. September 1, 2009).
# * If the month is missing (e.g. 2010), assume it is the first of January of that year (e.g. January 1, 2010).
# * Watch out for potential typos as this is a raw, real-life derived dataset.
#
# With these rules in mind, find the correct date in each note and return a pandas Series in chronological order of the original Series' indices.
#
# For example if the original series was this:
#
#     0    1999
#     1    2010
#     2    1978
#     3    2015
#     4    1985
#
# Your function should return this:
#
#     0    2
#     1    4
#     2    0
#     3    1
#     4    3
#
# Your score will be calculated using [Kendall's tau](https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient), a correlation measure for ordinal data.
#
# *This function should return a Series of length 500 and dtype int.*

# %%
import pandas as pd

doc = []
with open('dates.txt') as file:
    for line in file:
        doc.append(line)

df = pd.Series(doc)
df.head(10)
# Out:
# 0         03/25/93 Total time of visit (in minutes):\n
# 1                       6/18/85 Primary Care Doctor:\n
# 2    sshe plans to move as of 7/8/71 In-Home Servic...
# 3                7 on 9/27/75 Audit C Score Current:\n
# 4    2/6/96 sleep studyPain Treatment Pain Level (N...
# 5                    .Per 7/06/79 Movement D/O note:\n
# 6    4, 5/18/78 Patient's thoughts about current su...
# 7    10/24/89 CPT Code: 90801 - Psychiatric Diagnos...
# 8                         3/7/86 SOS-10 Total Score:\n
# 9             (4/10/71)Score-1Audit C Score Current:\n
# dtype: object

# %%
import re

# %%
with open('dates.txt') as file:
    for line in file:
    # looks for either mm/dd/yyyy or dd/mm/yyyy 
        three_date_config = re.search('[0-9]{2}/[0-9]{2}/[0-9]{4}',line)
        two_dates = re.search('^Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec\s[0-9]{4}',line)
        print(two_dates)
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <_sre.SRE_Match object; span=(28, 31), match='Mar'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <_sre.SRE_Match object; span=(4, 7), match='Sep'>
# <_sre.SRE_Match object; span=(29, 32), match='May'>
# <_sre.SRE_Match object; span=(68, 71), match='Jun'>
# <_sre.SRE_Match object; span=(3, 6), match='May'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Nov'>
# <_sre.SRE_Match object; span=(35, 38), match='Jun'>
# None
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Feb'>
# <_sre.SRE_Match object; span=(64, 67), match='Feb'>
# <_sre.SRE_Match object; span=(335, 338), match='Feb'>
# <_sre.SRE_Match object; span=(8, 11), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Feb'>
# <_sre.SRE_Match object; span=(3, 6), match='May'>
# None
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Nov'>
# <_sre.SRE_Match object; span=(3, 6), match='May'>
# <_sre.SRE_Match object; span=(7, 10), match='Feb'>
# <_sre.SRE_Match object; span=(3, 6), match='Sep'>
# <_sre.SRE_Match object; span=(3, 6), match='Mar'>
# <_sre.SRE_Match object; span=(3, 6), match='Jun'>
# <_sre.SRE_Match object; span=(3, 6), match='Sep'>
# None
# <_sre.SRE_Match object; span=(3, 6), match='Mar'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='May'>
# <_sre.SRE_Match object; span=(70, 73), match='Feb'>
# <_sre.SRE_Match object; span=(3, 6), match='Aug'>
# <_sre.SRE_Match object; span=(42, 45), match='May'>
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Mar'>
# None
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Aug'>
# <_sre.SRE_Match object; span=(3, 6), match='Nov'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# None
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Aug'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# <_sre.SRE_Match object; span=(7, 15), match='Dec 1988'>
# <_sre.SRE_Match object; span=(7, 10), match='Oct'>
# <_sre.SRE_Match object; span=(29, 32), match='May'>
# <_sre.SRE_Match object; span=(288, 291), match='Jul'>
# <_sre.SRE_Match object; span=(3, 6), match='Jun'>
# <_sre.SRE_Match object; span=(7, 15), match='Dec 1982'>
# <_sre.SRE_Match object; span=(7, 15), match='Dec 1988'>
# <_sre.SRE_Match object; span=(3, 6), match='Aug'>
# <_sre.SRE_Match object; span=(7, 10), match='Jun'>
# <_sre.SRE_Match object; span=(29, 32), match='May'>
# <_sre.SRE_Match object; span=(3, 6), match='Nov'>
# <_sre.SRE_Match object; span=(7, 10), match='Aug'>
# <_sre.SRE_Match object; span=(3, 6), match='Oct'>
# None
# <_sre.SRE_Match object; span=(3, 6), match='Mar'>
# <_sre.SRE_Match object; span=(8, 11), match='Oct'>
# <_sre.SRE_Match object; span=(7, 10), match='Aug'>
# <_sre.SRE_Match object; span=(3, 6), match='Nov'>
# <_sre.SRE_Match object; span=(3, 6), match='May'>
# <_sre.SRE_Match object; span=(260, 263), match='Jul'>
# <_sre.SRE_Match object; span=(0, 3), match='Apr'>
# <_sre.SRE_Match object; span=(4, 7), match='May'>
# <_sre.SRE_Match object; span=(1, 4), match='Feb'>
# <_sre.SRE_Match object; span=(13, 16), match='Feb'>
# <_sre.SRE_Match object; span=(66, 69), match='Oct'>
# None
# <_sre.SRE_Match object; span=(0, 3), match='Jul'>
# None
# <_sre.SRE_Match object; span=(0, 3), match='May'>
# <_sre.SRE_Match object; span=(0, 3), match='Sep'>
# <_sre.SRE_Match object; span=(0, 3), match='Mar'>
# None
# <_sre.SRE_Match object; span=(51, 54), match='Oct'>
# <_sre.SRE_Match object; span=(2, 5), match='Aug'>
# <_sre.SRE_Match object; span=(0, 3), match='Sep'>
# <_sre.SRE_Match object; span=(0, 3), match='Jul'>
# <_sre.SRE_Match object; span=(0, 3), match='Aug'>
# <_sre.SRE_Match object; span=(0, 3), match='Apr'>
# <_sre.SRE_Match object; span=(4, 7), match='Jul'>
# <_sre.SRE_Match object; span=(0, 3), match='Jul'>
# <_sre.SRE_Match object; span=(720, 723), match='Sep'>
# <_sre.SRE_Match object; span=(1, 4), match='Aug'>
# <_sre.SRE_Match object; span=(0, 3), match='Nov'>
# <_sre.SRE_Match object; span=(2, 5), match='Jun'>
# <_sre.SRE_Match object; span=(0, 3), match='May'>
# None
# <_sre.SRE_Match object; span=(132, 135), match='Jun'>
# <_sre.SRE_Match object; span=(0, 3), match='Oct'>
# <_sre.SRE_Match object; span=(0, 3), match='May'>
# <_sre.SRE_Match object; span=(416, 419), match='Oct'>
# <_sre.SRE_Match object; span=(0, 3), match='Jul'>
# <_sre.SRE_Match object; span=(0, 3), match='Jun'>
# None
# <_sre.SRE_Match object; span=(0, 3), match='Sep'>
# <_sre.SRE_Match object; span=(109, 112), match='Sep'>
# <_sre.SRE_Match object; span=(117, 120), match='Jun'>
# <_sre.SRE_Match object; span=(212, 215), match='May'>
# <_sre.SRE_Match object; span=(297, 300), match='May'>
# <_sre.SRE_Match object; span=(99, 102), match='Jul'>
# <_sre.SRE_Match object; span=(61, 64), match='Jul'>
# <_sre.SRE_Match object; span=(39, 42), match='Jul'>
# <_sre.SRE_Match object; span=(1, 4), match='Oct'>
# <_sre.SRE_Match object; span=(65, 68), match='May'>
# <_sre.SRE_Match object; span=(18, 21), match='Feb'>
# None
# <_sre.SRE_Match object; span=(5, 8), match='Feb'>
# <_sre.SRE_Match object; span=(29, 32), match='May'>
# <_sre.SRE_Match object; span=(170, 173), match='May'>
# <_sre.SRE_Match object; span=(16, 19), match='Nov'>
# <_sre.SRE_Match object; span=(4, 7), match='Sep'>
# None
# <_sre.SRE_Match object; span=(1, 4), match='Nov'>
# <_sre.SRE_Match object; span=(16, 19), match='Jul'>
# <_sre.SRE_Match object; span=(1, 4), match='May'>
# <_sre.SRE_Match object; span=(79, 82), match='Jul'>
# <_sre.SRE_Match object; span=(48, 51), match='Apr'>
# <_sre.SRE_Match object; span=(196, 199), match='May'>
# None
# None
# <_sre.SRE_Match object; span=(10, 13), match='Feb'>
# <_sre.SRE_Match object; span=(71, 74), match='Aug'>
# <_sre.SRE_Match object; span=(40, 43), match='Oct'>
# <_sre.SRE_Match object; span=(1, 4), match='Aug'>
# <_sre.SRE_Match object; span=(2, 5), match='Sep'>
# <_sre.SRE_Match object; span=(19, 22), match='Apr'>
# <_sre.SRE_Match object; span=(25, 28), match='Nov'>
# <_sre.SRE_Match object; span=(28, 31), match='Feb'>
# <_sre.SRE_Match object; span=(322, 325), match='Oct'>
# <_sre.SRE_Match object; span=(29, 32), match='Jun'>
# <_sre.SRE_Match object; span=(22, 25), match='Sep'>
# <_sre.SRE_Match object; span=(100, 103), match='Jun'>
# <_sre.SRE_Match object; span=(589, 592), match='Apr'>
# <_sre.SRE_Match object; span=(0, 3), match='Sep'>
# <_sre.SRE_Match object; span=(11, 14), match='Oct'>
# <_sre.SRE_Match object; span=(70, 78), match='Dec 2009'>
# <_sre.SRE_Match object; span=(44, 47), match='Jul'>
# <_sre.SRE_Match object; span=(0, 3), match='May'>
# <_sre.SRE_Match object; span=(462, 465), match='Aug'>
# <_sre.SRE_Match object; span=(806, 809), match='Feb'>
# <_sre.SRE_Match object; span=(25, 28), match='Feb'>
# <_sre.SRE_Match object; span=(5, 8), match='Apr'>
# <_sre.SRE_Match object; span=(47, 50), match='Sep'>
# <_sre.SRE_Match object; span=(0, 3), match='Apr'>
# <_sre.SRE_Match object; span=(99, 102), match='Apr'>
# <_sre.SRE_Match object; span=(6, 9), match='Sep'>
# <_sre.SRE_Match object; span=(4, 7), match='Sep'>
# <_sre.SRE_Match object; span=(41, 44), match='Jul'>
# <_sre.SRE_Match object; span=(1, 4), match='Aug'>
# <_sre.SRE_Match object; span=(386, 389), match='May'>
# <_sre.SRE_Match object; span=(1, 4), match='Feb'>
# None
# <_sre.SRE_Match object; span=(1, 4), match='Sep'>
# None
# <_sre.SRE_Match object; span=(85, 88), match='Mar'>
# <_sre.SRE_Match object; span=(19, 22), match='Aug'>
# <_sre.SRE_Match object; span=(21, 24), match='Sep'>
# None
# None
# <_sre.SRE_Match object; span=(40, 43), match='Nov'>
# <_sre.SRE_Match object; span=(219, 222), match='Sep'>
# <_sre.SRE_Match object; span=(0, 3), match='Feb'>
# <_sre.SRE_Match object; span=(15, 18), match='Mar'>
# <_sre.SRE_Match object; span=(52, 55), match='Aug'>
# <_sre.SRE_Match object; span=(66, 69), match='Mar'>
# None
# <_sre.SRE_Match object; span=(0, 3), match='Mar'>
# None
# <_sre.SRE_Match object; span=(17, 25), match='Dec 1992'>
# <_sre.SRE_Match object; span=(58, 61), match='Nov'>
# None
# <_sre.SRE_Match object; span=(101, 104), match='Mar'>
# <_sre.SRE_Match object; span=(34, 37), match='Feb'>
# <_sre.SRE_Match object; span=(0, 3), match='May'>
# <_sre.SRE_Match object; span=(177, 180), match='Jul'>
# <_sre.SRE_Match object; span=(56, 59), match='Feb'>
# <_sre.SRE_Match object; span=(69, 72), match='Apr'>
# <_sre.SRE_Match object; span=(48, 51), match='Oct'>
# <_sre.SRE_Match object; span=(23, 26), match='Feb'>
# <_sre.SRE_Match object; span=(572, 575), match='Feb'>
# None
# None
# <_sre.SRE_Match object; span=(34, 37), match='Jun'>
# <_sre.SRE_Match object; span=(42, 45), match='May'>
# <_sre.SRE_Match object; span=(659, 662), match='Mar'>
# None
# <_sre.SRE_Match object; span=(31, 34), match='Jul'>
# <_sre.SRE_Match object; span=(382, 385), match='Nov'>
# <_sre.SRE_Match object; span=(1, 4), match='Jun'>
# <_sre.SRE_Match object; span=(12, 15), match='Oct'>
# <_sre.SRE_Match object; span=(22, 25), match='Mar'>
# <_sre.SRE_Match object; span=(34, 37), match='Oct'>
# <_sre.SRE_Match object; span=(122, 125), match='Jun'>
# <_sre.SRE_Match object; span=(137, 140), match='Oct'>
# <_sre.SRE_Match object; span=(119, 122), match='Apr'>
# <_sre.SRE_Match object; span=(287, 290), match='May'>
# <_sre.SRE_Match object; span=(24, 27), match='Mar'>
# <_sre.SRE_Match object; span=(99, 102), match='Apr'>
# None
# <_sre.SRE_Match object; span=(13, 16), match='Jun'>
# <_sre.SRE_Match object; span=(1, 4), match='Nov'>
# <_sre.SRE_Match object; span=(17, 20), match='Jul'>
# <_sre.SRE_Match object; span=(116, 119), match='Feb'>
# <_sre.SRE_Match object; span=(51, 54), match='Mar'>
# <_sre.SRE_Match object; span=(69, 77), match='Dec 2007'>
# <_sre.SRE_Match object; span=(75, 78), match='Apr'>
# <_sre.SRE_Match object; span=(132, 135), match='Mar'>
# <_sre.SRE_Match object; span=(184, 187), match='May'>
# <_sre.SRE_Match object; span=(1, 4), match='Nov'>
# <_sre.SRE_Match object; span=(19, 22), match='Mar'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <_sre.SRE_Match object; span=(90, 93), match='Mar'>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
import re
filepath = 'dates.txt'


text = []
with open(filepath) as fp:
    text = fp.read()
str1 = ''.join(text)


regex = r"\d{1,2}\/\d{1,2}\/\d{2,4}|\d{1,2}\-\d{1,2}\-\d{2,4}|\d{2}\s[a-z]{3,8}\s\d{4}|\w*.?[\s\d{2}]?,?\s\d{4}"
matches = re.findall(regex, str1)


regex2 = r"[C|c][a-z]*:\s\d{4}"
remove_matches =  re.findall(regex2, ''.join(matches))

for cnt, match in enumerate(remove_matches):
    matches.remove(match)

print(matches)
# Out:
# ['03/25/93', '6/18/85', '7/8/71', '9/27/75', '2/6/96', '7/06/79', '5/18/78', '10/24/89', '3/7/86', '4/10/71', '5/11/85', '4/09/75', '8/01/98', '1/26/72', '5/24/1990', '1/25/2011', '4/12/82', '10/13/1976', '4/24/98', '5/21/77', '7/21/98', '10/21/79', '3/03/90', '2/11/76', '07/25/1984', '4-13-82', '9/22/89', '9/02/76', '9/12/71', '10/24/86', '03/31/1985', '7/20/72', '4/12/87', '06/20/91', '5/12/2012', '3/15/83', '2/14/73', '5/24/88', '7/27/1986', '1-14-81', '7-29-75', '6/24/87', '8/14/94', '4/13/2002', '8/16/82', '2/15/1998', '7/15/91', '06/12/94', '9/17/84', '2/28/75', '11/22/75', '5/24/91', '6/13/92', '7/11/71', '12/26/86', '10/11/1987', '3/14/95', '12/01/73', '12/5/2010', '08/20/1982', '7/24/95', '8/06/83', '02/22/92', '6/28/87', '07/29/1994', '08/11/78', '10/29/91', '7/6/91', '1/21/87', '11/3/1985', '7/04/82', '4-13-89', '7/11/77', '9/36/308', '4/12/74', '09/19/81', '9/6/79', '12/5/87', '01/05/1999', '4/22/80', '10/04/98', '6/29/81', '8/04/78', '7/07/1974', '09/14/2000', '5/18/71', '8/09/1981', '6/05/93', '8/9/97', '12/8/82', '8/26/89', '10/13/95', '4/19/91', '04/08/2004', '9/20/76', '12/08/1990', '4/11/1974', '7/18/86', '3/31/91', '5/13/72', '11/14/83', '8/16/92', '10/05/97', '07/18/2002', '9/22/82', '2/24/74', '2/03/78', '2/11/2006', '8/22/83', '5/04/74', '7/20/2011', '6/17/95', '6/10/72', '10/16/82', '12/15/92', '12/8/97', '4/05/89', '12/04/87', '6/20/77', '4/27/2006', '07/17/92', '12/22/98', '10/02/96', '11/05/90', '5/04/77', '2/27/96', 'Jan 2001', 'Sep 2004', 'May 1982', 'June 2002', 'May 1972', 'Oct 1987', 'Oct 1996', 'Nov 2007', 'June 1994', 'Jan 1981', 'Oct 1985', 'February 1985', 'Feb 1983', 'Feb 1992', 'Oct 2012', 'Feb 1995', 'May 2016', 'Jan 1996', 'Oct 1992', 'Oct 2003', 'Oct 1999', 'Nov 2004', 'May 2001', 'Feb 1978', 'Sep 1989', 'March 1980', 'June 1990', 'Sep 2015', 'Jan 1972', 'Mar 1974', 'Oct 1974', 'May 1974', 'Feb 1990', 'Aug 2000', 'May 2001', 'Oct 2007', 'Oct 2016', 'Mar 1974', 'Jan 1994', 'Oct 1978', 'August 1975', 'Nov 1996', 'Oct 1979', 'Oct 1986', 'Oct 1995', 'Jan 2011', 'Oct 1972', 'Aug 1993', 'Oct 2006', 'Dec 1988', 'Oct 1983', 'May 2010', 'Jan 1990', 'Jun 1985', 'Dec 1982', 'Dec 1988', 'August 1995', 'June 1974', 'May 2008', 'Nov 2002', 'Aug 1985', 'Oct 2016', 'Jan 2008', 'March 2004', 'Oct 1977', 'Aug 2000', 'Nov 1972', 'May 1993', 'Jan 1995', '11, 1990', '30, 2001', '18, 1994', '18, 1981', '11, 2013', '24 1986', '26, 1978', '23, 1999', '15, 1989', '06, 1995', '10, 1976', '27, 1983', '23 1990', '12 2004', '01, 2012', '25, 1983', '11, 1989', '17, 1992', '24, 1999', '11, 1997', '10, 1974', '14, 1981', '11, 1988', '13, 2011', '14, 1989', '14 1975', '25, 2012', '18, 1980', '15, 1998', '14 1974', '25, 1998', '15, 1972', '07, 1991', '15, 2011', 'September 1985', 'June 2011', 'May 1986', 'May 2016', 'July 1977', 'July, 1990', 'Jul 2003', 'pOct 2015', 'May 1995', 'February 1976', 'January 1995', 'Feb 1978', 'May, 2011', 'May 2004', 'Nov 2010', 'Sep 2012', 'January, 2013', 'lNovember 1990', 'July 1981', 'May 1983', 'July 1995', 'April 1993', 'May 2005', 'December 1998', 'Jan 2007', 'Feb 2016', 'August 1979', 'Oct 2014', 'IAug 1988', 'Sep 2015', 'Apr 1976', 'Nov 1979', 'February 2000', 'Oct 1986', 'Jun 2002', 'September 1981', 'June 2007', 'April 1989', 'September 1999', 'Oct 1980', 'Dec 2009', 'July 1992', 'May, 2006', 'August 2008', 'Feb 1993', 'February, 2010', 'April 1985', 'September 1984', 'April 1986', 'Apr 2007', 'September 1974', 'Sep 2013', 'July 1985', 'yAug 2004', 'May 2012', 'AFeb 1977', 'Jan 1987', 'sSep 1983', 'January 2013', 'Mar 2010', 'August 2009', 'Sep 2007', 'December 2011', 'Jan 2004', 'November 1995', 'September 2008', 'February 1983', 'March 1983', 'Aug 1979', 'Jan 2009', 'Janaury 1993', 'March 1974', 'January 1994', 'Dec 1992', 'November 2004', 'January 1977', 'Mar 2002', 'Feb 2000', 'May, 2004', 'July 2006', 'Feb 1994', 'April 1977', 'Oct 1992', 'February, 1995', 'February 1989', 'Decemeber 1978', 'January 2007', 'Jun 1976', 'May 2011', 'Mar, 1975', 'Jan 1978', 'July 1975', 'Novemb ...
